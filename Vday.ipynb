# %%
import math as math 
import numpy as np
from numpy import log as ln
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# datapool
data1=np.linspace(0,2*np.pi,100)
data2=np.linspace(np.pi,2*np.pi,100)
data3=np.linspace(-np.pi,np.pi,100)
data4=np.linspace(-6/4*np.pi,3/8*np.pi,100)
data5=np.linspace(0,1/2*np.pi,100)
c='b'

# %%
# this is letter A
def LA(i,j,c):
    data4
    x=np.arange(0.55,2.3,0.05)
    axs[i,j].plot(x+0.35,1/x-1.4,lw=3,c=c)
    axs[i,j].plot(np.sin(data4),np.cos(data4),lw=3,c=c)
    axs[i,j].axis('off')

# %%
# this is letter B
def LB(i,j,c):
    data3
    axs[i,j].plot(3*abs(np.sin(data3)),data3,lw=3,c=c)
    axs[i,j].plot([0,0],[-3.15,3.15],lw=3,c=c)
    axs[i,j].axis('off')

# %%
# this is letter C
def LC(i,j,c):
    data1
    axs[i,j].plot(-abs(np.sin(data1)),np.cos(data1),lw=3,c=c)
    axs[i,j].axis('off')

# %%
# this is letter D
def LD(i,j,c):
    data1
    axs[i,j].plot(-abs(np.sin(data1)),np.cos(data1),lw=3,c=c)
    axs[i,j].plot([0,0],[-1,5],lw=3,c=c)
    axs[i,j].axis('off')

# %%
# this is letter E
def LE(i,j,c):
    data3
    axs[i,j].plot(-3*abs(np.sin(data3)),data3,lw=3,c=c)
    axs[i,j].axis('off')

# %%
# this is letter F
def LF(i,j,c):
    x=np.arange(1,250,0.05)
    axs[i,j].plot(x,ln(x),lw=3,c=c)
    axs[i,j].plot([-100,200],[3,3],lw=3,c=c)
    axs[i,j].axis('off')

# %%
# this is letter G
def LG(i,j,c):
    data1
    axs[i,j].plot(np.cos(data1),-abs(np.sin(data1)),lw=2.5,c=c)
    axs[i,j].plot(np.cos(data1),np.sin(data1)+3,lw=2.5,c=c)
    axs[i,j].plot([0.98,0.98],[0,3],lw=3,c=c)
    axs[i,j].axis('off')

# %%
# this is letter H
def LH(i,j,c):
    data1
    axs[i,j].plot(np.cos(data1),abs(np.sin(data1)),lw=2.5,c=c)
    axs[i,j].plot([-1.02,-1.02],[-1,3],lw=3,c=c)
    axs[i,j].plot([0.98,0.98],[0,-1],lw=3,c=c)
    axs[i,j].axis('off')

# %%
# this is letter I
def LI(i,j,c):
    axs[i,j].scatter(2,5,s=80,c=c)
    axs[i,j].plot([2,2],[0,4.5],lw=3,c=c)
    axs[i,j].axis('off')

# %%
# this is letter J
def LJ(i,j,c):
    axs[i,j].scatter(2,5,s=80,c=c)
    axs[i,j].plot([2,2,2,2,2,2,2,2],[0.5,1,1.5,2,2.5,3,3.5,4],lw=3,c=c)
    axs[i,j].plot(1+np.cos(data2),0.5+np.sin(data2),lw=3,c=c)
    axs[i,j].axis('off')

# %%
# this is letter K
def LK(i,j,c):
    data1
    x=np.arange(0.45,2.5,0.05)
    axs[i,j].plot(np.cos(data1),np.sin(data1)+1,lw=2.5,c=c)
    axs[i,j].plot([-1.05,-1.05],[-1,3],lw=3,c=c)
    axs[i,j].plot(x-1.45,1/x-1.4,lw=3,c=c)
    axs[i,j].axis('off')

# %%
# this is letter L
def LL(i,j,c):
    x=np.arange(1,150,0.05)
    axs[i,j].plot(x,1/x,lw=3,c=c)
    axs[i,j].axis('off')

# %%
# this is letter M
def LM(i,j,c):
    data1
    x=np.arange(0.58,1,0.05)
    axs[i,j].plot(np.cos(data1),abs(np.sin(data1)),lw=2.5,c=c)
    axs[i,j].plot([-1.02,-1.02],[-0.25,0.25],lw=3,c=c)
    axs[i,j].plot([0.98,0.98],[0,-0.25],lw=3,c=c)
    axs[i,j].plot(-x-0.43,-1/x+1.93,lw=3,c=c)
    
    axs[i,j].plot(np.cos(data1)+2,abs(np.sin(data1)),lw=2.5,c=c)
    axs[i,j].plot([1.02,1.02],[-0.25,0.25],lw=3,c=c)
    axs[i,j].plot([2.98,2.98],[0,-0.25],lw=3,c=c)
    axs[i,j].axis('off')

# %%
# this is letter N
def LN(i,j,c):
    data1
    x=np.arange(0.58,1,0.05)
    axs[i,j].plot(np.cos(data1),abs(np.sin(data1)),lw=2.5,c=c)
    axs[i,j].plot([-1.02,-1.02],[-1,0.25],lw=3,c=c)
    axs[i,j].plot([0.98,0.98],[0,-1],lw=3,c=c)
    axs[i,j].plot(-x-0.43,-1/x+1.93,lw=3,c=c)
    axs[i,j].axis('off')

# %%
# this is letter O
def LO(i,j,c):
    data1
    axs[i,j].plot(3*np.cos(data1),3*np.sin(data1),lw=3,c=c)
    axs[i,j].axis('off')

# %%
# this is letter P
def LP(i,j,c):
    data1
    axs[i,j].plot(abs(1.5*np.sin(data1)),1.5*np.cos(data1)+3.5,lw=3,c=c)
    axs[i,j].plot([0,0],[-1,5],lw=3,c=c)
    axs[i,j].axis('off')

# %%
# this is letter Q
def LQ(i,j,c):
    data1
    axs[i,j].plot(1.5*np.sin(data1),1.5*np.cos(data1)+3.5,lw=3,c=c)
    axs[i,j].plot([1.46,1.46],[-1,3.5],lw=3,c=c)
    axs[i,j].axis('off')

# %%
# this is letter R
def LR(i,j,c):
    y=np.linspace(2/6*np.pi,5/8*np.pi,100)
    x=np.linspace(0,1/6*np.pi,100)
    axs[i,j].plot(y-1.04,np.sin(y)+0.15,lw=2.5,c=c)
    axs[i,j].plot(x-0.51,np.cos(x)+0.18,lw=2.5,c=c)
    axs[i,j].plot([0,0],[0.95,1.05],lw=3,c=c)
    axs[i,j].axis('off')

# %%
# this is letter S
def LS(i,j,c):
    y=np.linspace(0,3/2*np.pi,100)
    x=np.linspace(0,1/2*np.pi,100)
    z=np.linspace(-np.pi,2*np.pi,100)
    axs[i,j].plot(np.cos(x),np.sin(x),lw=3,c=c)
    axs[i,j].plot(np.cos(y),np.sin(y)+2,lw=3,c=c)
    axs[i,j].plot(np.cos(z),-abs(np.sin(z)),lw=3,c=c)
    axs[i,j].axis('off')

# %%
# this is letter T
def LT(i,j,c):
    data1
    axs[i,j].plot(np.cos(data1),-abs(np.sin(data1)),lw=3,c=c)
    axs[i,j].plot([-1.02,-1.02],[0,3],lw=3,c=c)
    axs[i,j].plot([-2.5,1],[1.5,1.5],lw=3,c=c)
    axs[i,j].axis('off')

# %%
# this is letter U
def LU(i,j,c):
    data1
    x=np.arange(0.58,1.6,0.05)
    axs[i,j].plot(np.cos(data1),-abs(np.sin(data1)),lw=2.5,c=c)
    axs[i,j].plot([-1.01,-1.01],[-0.1,0.25],lw=3,c=c)
    axs[i,j].plot([0.99,0.99],[0,0.25],lw=3,c=c)
    axs[i,j].plot(x+0.43,1/x-1.6,lw=3,c=c)
    axs[i,j].axis('off')

# %%
# this is letter V
def LV(i,j,c):
    x=np.arange(-2,2.05,0.05)
    axs[i,j].plot(x,abs(-2*x),lw=3,c=c)
    axs[i,j].axis('off')

# %%
# this is letter W
def LW(i,j,c):
    data1
    x=np.arange(0.58,1.6,0.05)
    axs[i,j].plot(np.cos(data1),-abs(np.sin(data1)),lw=2.5,c=c)
    axs[i,j].plot([-1.01,-1.01],[-0.1,0.25],lw=3,c=c)
    axs[i,j].plot([0.99,0.99],[0,0.25],lw=3,c=c)

    axs[i,j].plot(np.cos(data1)+2,-abs(np.sin(data1)),lw=2.5,c=c)
    axs[i,j].plot([0.99,0.99],[-0.1,0.25],lw=3,c=c)
    axs[i,j].plot([2.99,2.99],[0,0.25],lw=3,c=c)
    axs[i,j].axis('off')

# %%
# this is letter X
def LX(i,j,c):
    x=np.linspace(1/2*np.pi,3/2*np.pi,100)
    y=np.linspace(np.pi,2*np.pi,100)
    axs[i,j].plot(y-1/2*np.pi,np.cos(y),lw=2.5,c=c)
    axs[i,j].plot(x,np.sin(x),lw=2.5,c=c)
    axs[i,j].axis('off')

# %%
# this is letter Y
def LY(i,j,c):
    data5
    axs[i,j].plot(data5-1/2*np.pi,np.cos(data5)+1,lw=2.5,c=c)
    axs[i,j].plot(data5,np.sin(data5)+1,lw=2.5,c=c)
    axs[i,j].plot([0,0],[-1,1],lw=3,c=c)
    axs[i,j].axis('off')

# %%
# this is letter Z
def LZ(i,j,c):
    axs[i,j].plot([0,4],[4,4],lw=3,c=c)
    axs[i,j].plot([0,4],[0,0],lw=3,c=c)
    axs[i,j].plot([0,4],[0,4],lw=3,c=c)
    axs[i,j].axis('off')

# %%
# this is "'"
def L(i,j,c):
    x=np.linspace(np.pi,3/2*np.pi,100)
    axs[i,j].plot(x-3,np.cos(x)+2,lw=2.5,c=c)
    axs[i,j].scatter(0,0,s=0.05)
    axs[i,j].scatter(2,2,s=0.05)
    axs[i,j].scatter(0,2,s=0.05)
    axs[i,j].scatter(2,0,s=0.05)
    axs[i,j].axis('off')

# %%
# this is the main :
nrows=6
ncols=12
fig,axs=plt.subplots(nrows,ncols,figsize=(24,36))
for i in range(6):
    for j in range(12):
        axs[i,j].axis('off')
LD(0,0,c)
LE(0,1,c)
LA(0,2,c)
LR(0,3,c)
LJ(0,6,c)
LO(0,7,c)
LE(0,8,c)
LH(1,2,c)
LA(1,3,c)
LP(1,4,c)
LP(1,5,c)
LY(1,6,c)
LV(2,0,c)
LA(2,1,c)
LL(2,2,c)
LE(2,3,c)
LN(2,4,c)
LT(2,5,c)
LI(2,6,c)
LN(2,7,c)
LE(2,8,c)
L(2,9,c)
LS(2,10,c)
LD(3,6,c)
LA(3,7,c)
LY(3,8,c)
LI(4,1,c)
LL(4,3,c)
LO(4,4,c)
LV(4,5,c)
LE(4,6,c)
LY(4,9,c)
LO(4,10,c)
LU(4,11,c)
LD(5,5,c)
LA(5,6,c)
LI(5,7,c)
LS(5,8,c)
LY(5,9,c)
